# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification,make_blobs
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
class LogisticRegressionClassifier:
    def __init__(self,lr=0.01,epochs=1000):
        self.lr = lr
        self.epochs = epochs

    def fit(self,X,y):
        X = np.column_stack((X,np.ones(shape = (X.shape[0],1))))
        self.th,self.errorGD = self.gradientDescent(X,y,self.lr,self.epochs)

    def predict(self,t):
        t = np.column_stack((t,np.ones(shape = (t.shape[0],1))))
        y_pred = self.hypothesis(t,self.th)
        y_pred[y_pred >= 0.5] = 1
        y_pred[y_pred < 0.5] = 0
        return y_pred.astype('int32')

    def predict_a(self,t,th):
        y_pred = self.hypothesis(t,th)
        y_pred[y_pred >= 0.5] = 1
        y_pred[y_pred < 0.5] = 0
        return y_pred.astype('int32')
        
    def hypothesis(self,x,th):
        # y_pred = np.zeros((x.shape[0],))
        # for i in range(len(x)):
        #     y_pred[i] = np.sum(x[i]*th)
        # return y_pred
    
        # return np.sum(x*th,axis = 1)
    
        return 1/(1+np.exp(-1*(th@x.T)))
    
    def error(self,x,th,y):
        y_pred = self.hypothesis(x,th)
        return -1*(y*np.log2(y_pred) + (1-y)*np.log2(1-y_pred)).sum()
    
    def gradientDescent(self,x,y,lr=0.01,epochs = 1000):
        th = np.zeros(x.shape[1])
        # print(th1,th0)
        errorGD = []
        for i in range(epochs+1):
            y_pred = self.hypothesis(x,th)
            # print(y_pred)
            #Gradient
            gradients = ((y_pred-y)@x)
            th = th - lr*gradients
    
            errorGD.append(self.error(x,th,y))
            # if i%1000 == 0:
            print(f"Epoch: {i+1}, Error: {errorGD[-1]}, accuracy score{self.acc_score(y,self.predict_a(x,th))}")
    
        return th,errorGD
    
    def acc_score(self,y_true,y_pred):
        return np.mean(y_true == y_pred)

# %%
X,y = make_classification(n_samples=500,n_features=2,n_informative=2,n_redundant=0,n_classes=2,random_state=42)

# %%
X = (X-X.mean(axis=0))/X.std(axis=0)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
clf = LogisticRegressionClassifier(lr = 0.01,epochs=100)
clf.fit(X,y)
# clf.predict(X)
# Out:
# Epoch: 1, Error: 238.50005406879157, accuracy score0.88
# Epoch: 2, Error: 222.28872666423663, accuracy score0.884
# Epoch: 3, Error: 215.05993258263572, accuracy score0.888
# Epoch: 4, Error: 210.96538816599266, accuracy score0.888
# Epoch: 5, Error: 208.40679834385895, accuracy score0.888
# Epoch: 6, Error: 206.7101630900053, accuracy score0.89
# Epoch: 7, Error: 205.53867159545342, accuracy score0.89
# Epoch: 8, Error: 204.70565999681915, accuracy score0.89
# Epoch: 9, Error: 204.099979601314, accuracy score0.89
# Epoch: 10, Error: 203.65184237203553, accuracy score0.89
# Epoch: 11, Error: 203.3156044719132, accuracy score0.89
# Epoch: 12, Error: 203.06043239521284, accuracy score0.89
# Epoch: 13, Error: 202.86494510493503, accuracy score0.89
# Epoch: 14, Error: 202.713993327193, accuracy score0.89
# Epoch: 15, Error: 202.59664848082645, accuracy score0.89
# Epoch: 16, Error: 202.50490624185818, accuracy score0.89
# Epoch: 17, Error: 202.43282785008637, accuracy score0.89
# Epoch: 18, Error: 202.37595797133653, accuracy score0.89
# Epoch: 19, Error: 202.3309220158084, accuracy score0.89
# Epoch: 20, Error: 202.2951426531182, accuracy score0.89
# Epoch: 21, Error: 202.26663713918833, accuracy score0.89
# Epoch: 22, Error: 202.24387043394063, accuracy score0.89
# Epoch: 78, Error: 202.14997092812922, accuracy score0.892
# Epoch: 79, Error: 202.14997076254025, accuracy score0.892
# Epoch: 80, Error: 202.1499706275753, accuracy score0.892
# Epoch: 81, Error: 202.14997051757018, accuracy score0.892
# Epoch: 82, Error: 202.14997042790867, accuracy score0.892
# Epoch: 83, Error: 202.14997035482816, accuracy score0.892
# Epoch: 84, Error: 202.14997029526222, accuracy score0.892
# Epoch: 85, Error: 202.14997024671146, accuracy score0.892
# Epoch: 86, Error: 202.14997020713872, accuracy score0.892
# Epoch: 87, Error: 202.14997017488383, accuracy score0.892
# Epoch: 88, Error: 202.1499701485934, accuracy score0.892
# Epoch: 89, Error: 202.14997012716452, accuracy score0.892
# Epoch: 90, Error: 202.14997010969816, accuracy score0.892
# Epoch: 91, Error: 202.14997009546153, accuracy score0.892
# Epoch: 92, Error: 202.14997008385745, accuracy score0.892
# Epoch: 93, Error: 202.14997007439905, accuracy score0.892
# Epoch: 94, Error: 202.14997006668963, accuracy score0.892
# Epoch: 95, Error: 202.14997006040576, accuracy score0.892
# Epoch: 96, Error: 202.1499700552838, accuracy score0.892
# Epoch: 97, Error: 202.14997005110894, accuracy score0.892
# Epoch: 98, Error: 202.14997004770606, accuracy score0.892
# Epoch: 99, Error: 202.1499700449324, accuracy score0.892
# Epoch: 100, Error: 202.14997004267155, accuracy score0.892
# Epoch: 101, Error: 202.14997004082878, accuracy score0.892

# %%
plt.plot(clf.errorGD)
plt.show()

# %%
X1 = np.linspace(-1,1,10)
X2 = -1*([clf.th[0]/clf.th[1]]*X1+[clf.th[2]/clf.th[1]])
plt.scatter(X[:,0],X[:,1],c=y)
plt.plot(X1,X2)
plt.show()

# %%
x1 = np.linspace(-2,2,100)
plt.scatter(X[:,0],y,c=y)
plt.plot(x1,1/(1+np.exp(-1*(clf.th[0]*x1))))
plt.grid()
plt.show()

# %%
x2 = np.linspace(-10,10,100)
plt.scatter(X[:,1],y,c=y)
plt.plot(x2,1/(1+np.exp(-1*(clf.th[1]*x2))))
plt.grid()
plt.show()

# %%
X = pd.read_csv("diabetes.csv",index_col=False, usecols=[0,1,2,3,4,5,6,7])
y = pd.read_csv("diabetes.csv",index_col=False, usecols=[8])

X_data,y_data = X.values , y.values
y_data=y_data.reshape(-1)
X_train,X_test,y_train,y_test = train_test_split(X_data,y_data,train_size=0.8,random_state=42)
std = StandardScaler()
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

# %%
clf = LogisticRegressionClassifier(lr = 0.01,epochs=100)
clf.fit(X_train,y_train)
# Out:
# Epoch: 1, Error: 493.09777479354926, accuracy score0.750814332247557
# Epoch: 2, Error: 419.1939431383769, accuracy score0.7703583061889251
# Epoch: 3, Error: 415.4268903725192, accuracy score0.7752442996742671
# Epoch: 4, Error: 414.7593046946287, accuracy score0.7752442996742671
# Epoch: 5, Error: 414.5672469644445, accuracy score0.7736156351791531
# Epoch: 6, Error: 414.48596210326554, accuracy score0.7736156351791531
# Epoch: 7, Error: 414.4556806351759, accuracy score0.7703583061889251
# Epoch: 8, Error: 414.4415762334875, accuracy score0.7736156351791531
# Epoch: 9, Error: 414.43552209863896, accuracy score0.7703583061889251
# Epoch: 10, Error: 414.4320091941953, accuracy score0.7736156351791531
# Epoch: 11, Error: 414.43004384025033, accuracy score0.7703583061889251
# Epoch: 60, Error: 414.41542373846664, accuracy score0.7703583061889251
# Epoch: 61, Error: 414.4154060431383, accuracy score0.7703583061889251
# Epoch: 62, Error: 414.4153896197901, accuracy score0.7703583061889251
# Epoch: 63, Error: 414.4153746922516, accuracy score0.7703583061889251
# Epoch: 64, Error: 414.4153608498091, accuracy score0.7703583061889251
# Epoch: 65, Error: 414.4153482575832, accuracy score0.7703583061889251
# Epoch: 66, Error: 414.41533659004045, accuracy score0.7703583061889251
# Epoch: 67, Error: 414.4153259681275, accuracy score0.7703583061889251
# Epoch: 68, Error: 414.4153161334437, accuracy score0.7703583061889251
# Epoch: 69, Error: 414.41530717381477, accuracy score0.7703583061889251
# Epoch: 70, Error: 414.4152988838148, accuracy score0.7703583061889251
# Epoch: 71, Error: 414.41529132653704, accuracy score0.7703583061889251
# Epoch: 72, Error: 414.41528433841177, accuracy score0.7703583061889251
# Epoch: 73, Error: 414.41527796415164, accuracy score0.7703583061889251
# Epoch: 74, Error: 414.4152720733032, accuracy score0.7703583061889251
# Epoch: 75, Error: 414.4152666969959, accuracy score0.7703583061889251
# Epoch: 76, Error: 414.41526173101397, accuracy score0.7703583061889251
# Epoch: 77, Error: 414.41525719651725, accuracy score0.7703583061889251
# Epoch: 78, Error: 414.41525301010813, accuracy score0.7703583061889251
# Epoch: 79, Error: 414.41524918568825, accuracy score0.7703583061889251
# Epoch: 80, Error: 414.4152456564036, accuracy score0.7703583061889251
# Epoch: 81, Error: 414.4152424309249, accuracy score0.7703583061889251
# Epoch: 82, Error: 414.4152394555649, accuracy score0.7703583061889251
# Epoch: 83, Error: 414.41523673527263, accuracy score0.7703583061889251
# Epoch: 84, Error: 414.4152342268572, accuracy score0.7703583061889251
# Epoch: 85, Error: 414.4152319326622, accuracy score0.7703583061889251
# Epoch: 86, Error: 414.4152298178785, accuracy score0.7703583061889251
# Epoch: 87, Error: 414.41522788306565, accuracy score0.7703583061889251
# Epoch: 88, Error: 414.41522610011856, accuracy score0.7703583061889251
# Epoch: 89, Error: 414.41522446841225, accuracy score0.7703583061889251
# Epoch: 90, Error: 414.4152229652133, accuracy score0.7703583061889251
# Epoch: 91, Error: 414.41522158914535, accuracy score0.7703583061889251
# Epoch: 92, Error: 414.41522032178665, accuracy score0.7703583061889251
# Epoch: 93, Error: 414.4152191613191, accuracy score0.7703583061889251
# Epoch: 94, Error: 414.41521809278777, accuracy score0.7703583061889251
# Epoch: 95, Error: 414.4152171141505, accuracy score0.7703583061889251
# Epoch: 96, Error: 414.415216213245, accuracy score0.7703583061889251
# Epoch: 97, Error: 414.4152153879552, accuracy score0.7703583061889251
# Epoch: 98, Error: 414.4152146283724, accuracy score0.7703583061889251
# Epoch: 99, Error: 414.41521393240714, accuracy score0.7703583061889251
# Epoch: 100, Error: 414.41521329197286, accuracy score0.7703583061889251
# Epoch: 101, Error: 414.4152127050712, accuracy score0.7703583061889251

# %%
plt.plot(clf.errorGD)
plt.show()

# %%
clf.acc_score(y_test,clf.predict(X_test))
# Out:
# 0.7532467532467533

# %%
data = pd.read_csv('titanic.csv')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
drop_column =["passengerId","Name","Ticket","Cabin"]

# %%
data = drop_column(data_drop=drop_comlum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 data = drop_column(data_drop=drop_comlum)
#
# NameError: name 'drop_comlum' is not defined
